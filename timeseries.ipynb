# %% [markdown]
# # 1. Dependencies

# %%
import numpy as np
import pandas as pd
from pandas import Grouper
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from statsmodels.tools.eval_measures import rmse
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.utils import *
import keras.metrics as metrics
import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# # 2. Data Preprocessing and Pipeline

# %%
train_df = pd.read_excel('./Train_dataset.xlsx', sheet_name='Diuresis_TS', )

# %%
train_df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10714 entries, 0 to 10713
# Data columns (total 8 columns):
# people_ID              10714 non-null int64
# 2020-03-20 00:00:00    10714 non-null int64
# 2020-03-21 00:00:00    10714 non-null float64
# 2020-03-22 00:00:00    10714 non-null float64
# 2020-03-23 00:00:00    10714 non-null float64
# 2020-03-24 00:00:00    10714 non-null float64
# 2020-03-25 00:00:00    10714 non-null float64
# 2020-03-26 00:00:00    10714 non-null float64
# dtypes: float64(6), int64(2)
# memory usage: 669.8 KB

# %%
people_ID = train_df.people_ID

train_copy = train_df.drop(columns=['people_ID'], axis=1)

# %%
cols = train_copy.columns

# %%
## infection rate is high on 26th March

# %%
# #infections vs date for a single people_ID
plt.plot([col.date().day for col in cols], train_copy.values[np.random.randint(0, train_copy.values.shape[1])]);

# %%
# infections counts for diff p_ids in a day
sns.countplot(x = cols[1], data = train_copy, order = train_copy[cols[1]].value_counts().index);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fff69da3615e> in <module>()
#       1 # infections counts for diff p_ids in a day
# ----> 2 sns.countplot(x = cols[1], data = train_copy, order = train_copy[cols[1]].value_counts().index);
#
# NameError: name 'sns' is not defined

# %%
train_df.head()
# Out:
#    people_ID  2020-03-20 00:00:00  ...  2020-03-25 00:00:00  2020-03-26 00:00:00
# 0          1                  441  ...           1215.68992          1472.627904
# 1          2                  151  ...            492.91072           606.892864
# 2          3                  416  ...           1150.32832          1395.793984
# 3          4                  410  ...           1126.78720          1368.344640
# 4          5                  390  ...           1084.40800          1315.889600
#
# [5 rows x 8 columns]

# %%
train_transpose = train_copy.transpose()

# %%
train_transpose.head()
# Out:
#                          0         1      ...     10712     10713
# 2020-03-20 00:00:00   441.0000  151.0000  ...  352.0000  181.0000
# 2020-03-21 00:00:00   544.2000  197.2000  ...  438.4000  230.2000
# 2020-03-22 00:00:00   669.6400  253.2400  ...  542.6800  290.4400
# 2020-03-23 00:00:00   821.3680  321.6880  ...  665.8160  366.3280
# 2020-03-24 00:00:00  1002.2416  399.9256  ...  814.6792  455.2936
#
# [5 rows x 10714 columns]

# %%
train_transpose[0]
# Out:
# 2020-03-20     441.000000
# 2020-03-21     544.200000
# 2020-03-22     669.640000
# 2020-03-23     821.368000
# 2020-03-24    1002.241600
# 2020-03-25    1215.689920
# 2020-03-26    1472.627904
# Name: 0, dtype: float64

# %%
cols_date = [datetime for col in cols]

# %%
date_df = pd.DataFrame(cols_date, columns=['date'])

# %%
train_transpose = train_copy.transpose()

# %%
train_transpose.head()
# Out:
#                          0         1      ...     10712     10713
# 2020-03-20 00:00:00   441.0000  151.0000  ...  352.0000  181.0000
# 2020-03-21 00:00:00   544.2000  197.2000  ...  438.4000  230.2000
# 2020-03-22 00:00:00   669.6400  253.2400  ...  542.6800  290.4400
# 2020-03-23 00:00:00   821.3680  321.6880  ...  665.8160  366.3280
# 2020-03-24 00:00:00  1002.2416  399.9256  ...  814.6792  455.2936
#
# [5 rows x 10714 columns]

# %%
# train_transpose

# %%
# set the index as date 
train_transpose['date'] = train_transpose.index

# %%
train_transpose.head()
# Out:
#                              0         1  ...     10713       date
# 2020-03-20 00:00:00   441.0000  151.0000  ...  181.0000 2020-03-20
# 2020-03-21 00:00:00   544.2000  197.2000  ...  230.2000 2020-03-21
# 2020-03-22 00:00:00   669.6400  253.2400  ...  290.4400 2020-03-22
# 2020-03-23 00:00:00   821.3680  321.6880  ...  366.3280 2020-03-23
# 2020-03-24 00:00:00  1002.2416  399.9256  ...  455.2936 2020-03-24
#
# [5 rows x 10715 columns]

# %%
# since we have date as index we no longer need index
train_transpose = train_transpose.reset_index(drop=True)

# %%
train_transpose.head()
# Out:
#            0         1         2  ...     10712     10713       date
# 0   441.0000  151.0000  416.0000  ...  352.0000  181.0000 2020-03-20
# 1   544.2000  197.2000  515.2000  ...  438.4000  230.2000 2020-03-21
# 2   669.6400  253.2400  632.4400  ...  542.6800  290.4400 2020-03-22
# 3   821.3680  321.6880  776.7280  ...  665.8160  366.3280 2020-03-23
# 4  1002.2416  399.9256  947.7736  ...  814.6792  455.2936 2020-03-24
#
# [5 rows x 10715 columns]

# %%
train_transpose = train_transpose.set_index(train_transpose.date)

# %%
train_transpose.head()
# Out:
#                     0         1         2  ...     10712     10713       date
# date                                       ...
# 2020-03-20   441.0000  151.0000  416.0000  ...  352.0000  181.0000 2020-03-20
# 2020-03-21   544.2000  197.2000  515.2000  ...  438.4000  230.2000 2020-03-21
# 2020-03-22   669.6400  253.2400  632.4400  ...  542.6800  290.4400 2020-03-22
# 2020-03-23   821.3680  321.6880  776.7280  ...  665.8160  366.3280 2020-03-23
# 2020-03-24  1002.2416  399.9256  947.7736  ...  814.6792  455.2936 2020-03-24
#
# [5 rows x 10715 columns]

# %%
train_transpose_copy = train_transpose.drop(columns=['date'], axis=1)

# %%
train_transpose_copy
# Out:
#                   0           1      ...        10712       10713
# date                                 ...
# 2020-03-20   441.000000  151.000000  ...   352.000000  181.000000
# 2020-03-21   544.200000  197.200000  ...   438.400000  230.200000
# 2020-03-22   669.640000  253.240000  ...   542.680000  290.440000
# 2020-03-23   821.368000  321.688000  ...   665.816000  366.328000
# 2020-03-24  1002.241600  399.925600  ...   814.679200  455.293600
# 2020-03-25  1215.689920  492.910720  ...   990.615040  559.352320
# 2020-03-26  1472.627904  606.892864  ...  1204.138048  686.622784
#
# [7 rows x 10714 columns]

# %%
train, test = train_transpose_copy[:6], train_transpose_copy[6:]

# %%
test.shape
# Out:
# (1, 10714)

# %% [markdown]
# ### Scaling the data(It will help to converge faster)

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
train = scaler.transform(train)
test = scaler.transform(test)

# %%
n_input = 1
n_features = train.shape[1]

# %%
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=1)

# %%
# TimeseriesGenerator?
# X[0].shape

# %% [markdown]
# ## LSTM Model for Time Series Prediction

# %%
def create_model():
    model = Sequential()
    model.add(LSTM(200, activation='relu', input_shape=(1, 10714)))
    model.add(Dropout(0.15))
    model.add(Dense(train.shape[1]))
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
model = create_model()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 200)               8732000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10714)             2153514
# =================================================================
# Total params: 10,885,514
# Trainable params: 10,885,514
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit_generator(generator,epochs=90)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.0/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/90
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 5/5 [==============================] - 9s 2s/step - loss: 0.3624
# Epoch 2/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2390
# Epoch 3/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1679
# Epoch 4/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0747
# Epoch 5/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0773
# Epoch 6/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2697
# Epoch 7/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1817
# Epoch 8/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1449
# Epoch 9/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2931
# Epoch 10/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1005
# Epoch 11/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.2519
# Epoch 12/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1079
# Epoch 13/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0979
# Epoch 14/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2000
# Epoch 15/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1826
# Epoch 16/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0602
# Epoch 17/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0550
# Epoch 18/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0512
# Epoch 19/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0149
# Epoch 20/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0318
# Epoch 21/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0187
# Epoch 22/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0330
# Epoch 23/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0064
# Epoch 24/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0179
# Epoch 25/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0296
# Epoch 26/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0091
# Epoch 27/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1302
# Epoch 28/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1243
# Epoch 29/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.1075
# Epoch 30/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0831
# Epoch 31/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0950
# Epoch 32/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0752
# Epoch 33/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0692
# Epoch 34/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0074
# Epoch 35/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0488
# Epoch 36/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0172
# Epoch 37/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0526
# Epoch 38/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0344
# Epoch 39/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0219
# Epoch 40/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0756
# Epoch 41/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0915
# Epoch 42/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0349
# Epoch 43/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0326
# Epoch 44/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0401
# Epoch 45/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0152
# Epoch 46/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0045
# Epoch 47/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0106
# Epoch 48/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0106
# Epoch 49/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0086
# Epoch 50/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0188
# Epoch 51/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0148
# Epoch 52/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0148
# Epoch 53/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0021
# Epoch 54/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0245
# Epoch 55/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0324
# Epoch 56/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0754
# Epoch 57/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0188
# Epoch 58/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0782
# Epoch 59/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0310
# Epoch 60/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0555
# Epoch 61/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0090
# Epoch 62/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0457
# Epoch 63/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0110
# Epoch 64/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0040
# Epoch 65/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0057
# Epoch 66/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0266
# Epoch 67/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0258
# Epoch 68/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0124
# Epoch 69/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0083
# Epoch 70/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0135
# Epoch 71/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0640
# Epoch 72/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0081
# Epoch 73/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0561
# Epoch 74/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0090
# Epoch 75/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0414
# Epoch 76/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0310
# Epoch 77/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0146
# Epoch 78/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0233
# Epoch 79/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0462
# Epoch 80/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0239
# Epoch 81/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0137
# Epoch 82/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0364
# Epoch 83/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0026
# Epoch 84/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0178
# Epoch 85/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0017
# Epoch 86/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0260
# Epoch 87/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0475
# Epoch 88/90
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0128
# Epoch 89/90
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0164
# Epoch 90/90
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0117

# %% [markdown]
# ### Inference

# %%
preds  = model.predict(test_copy)

# %%
preds_scaled = scaler.inverse_transform(preds)

# %%
preds_scaled.shape
# Out:
# (1, 10714)

# %%
results = np.transpose(preds_scaled)

# %%
# results = results.squeeze()

# %%
print(f'results and people_ID shape should be equal = {results.shape == people_ID.shape}')
# Out:
# results and people_ID shape should be equal = True

# %%
re
# Out:
# array([1650.2976 ,  676.8725 , 1551.861  , ...,  769.66376, 1347.9252 ,
#         764.40564], dtype=float32)

# %%
results.shape
# Out:
# (10714, 1)

# %%
results_df = pd.DataFrame(data=results, columns = ["2020-03-27"])

# %%
covid19_time_series = pd.concat([train_df.people_ID, results_df], axis=1)

# %%
covid19_time_series.head()
# Out:
#    people_ID   2020-03-27
# 0          1  1650.297607
# 1          2   676.872498
# 2          3  1551.860962
# 3          4  1497.703613
# 4          5  1450.746826

# %%
covid19_time_series["2020-03-27"].plot(kind="kde", figsize=(16, 8))

# %%
covid19_time_series["2020-03-27"].plot(kind="line", figsize=(16, 8));

# %%
covid19_time_series.to_csv("covid19_time_series.csv", index=None)
